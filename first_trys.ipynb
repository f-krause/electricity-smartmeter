# %%
from src.vienna_smartmeter.client import Smartmeter
from credentials import username, password

api = Smartmeter(username, password)
print(api.profil())
# Out:
# {'id': 29293, 'salutation': 'Herr', 'firstname': 'Felix Elias', 'lastname': 'Krause', 'email': 'felix_krause1999@yahoo.de', 'zustimmung': None, 'registration': {'registrationKey': '333125555972', 'zaehlpunkt': 'AT0010000000000000001000014166809', 'status': 'CONFIRMED', 'completedAt': '2021-11-14T12:24:50.061Z'}, 'defaultGeschaeftspartnerRegistration': {'id': 18374, 'registrationKey': '333125555972', 'zaehlpunkt': 'AT0010000000000000001000014166809', 'status': 'CONFIRMED', 'geschaeftspartner': '1203145924', 'completedAt': '2021-11-14T12:24:50.061Z'}, 'isZpsDonee': False}

# %%
from datetime import datetime
from_date = datetime(2022, 6, 1)

# %%
# Verbrauch in Wh (?)
api.verbrauch_raw(from_date)
# Out:
# {'quarter-hour-opt-in': True,
#  'values': [{'value': 5430,
#    'timestamp': '2022-06-01T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 4861,
#    'timestamp': '2022-06-02T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 6461,
#    'timestamp': '2022-06-03T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 5474,
#    'timestamp': '2022-06-04T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 4081,
#    'timestamp': '2022-06-05T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 6573,
#    'timestamp': '2022-06-06T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 6120,
#    'timestamp': '2022-06-07T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 7962,
#    'timestamp': '2022-06-08T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 6920,
#    'timestamp': '2022-06-09T22:00:00.000Z',
#    'isEstimated': False},
#   {'value': 8318,
#    'timestamp': '2022-06-10T22:00:00.000Z',
#    'isEstimated': False},
# ...

# %%
# Ereignisse
api.ereignisse(from_date)
# Out:
# [{'id': 12927,
#   'name': 'Villach',
#   'typ': 'ZEITSPANNE',
#   'zaehlpunkt': 'AT0010000000000000001000014166809',
#   'startAt': '2023-04-09T22:00:00Z',
#   'endAt': '2023-04-15T21:55:00Z'},
#  {'id': 11864,
#   'name': '1. Stock Heizung wieder eingeschaltet',
#   'typ': 'ZEITPUNKT',
#   'zaehlpunkt': 'AT0010000000000000001000014166809',
#   'startAt': '2023-03-13T11:00:00Z',
#   'endAt': '2023-03-13T11:00:00Z'},
#  {'id': 10316,
#   'name': 'Deutschland',
#   'typ': 'ZEITSPANNE',
#   'zaehlpunkt': 'AT0010000000000000001000014166809',
#   'startAt': '2023-02-04T23:00:00Z',
#   'endAt': '2023-02-12T22:55:00Z'},
#  {'id': 10315,
#   'name': 'Deutschland',
#   'typ': 'ZEITSPANNE',
#   'zaehlpunkt': 'AT0010000000000000001000014166809',
#   'startAt': '2022-12-22T23:00:00Z',
#   'endAt': '2022-12-29T22:55:00Z'},
#  {'id': 5684,
#   'name': 'Jessy Auszug',
#   'typ': 'ZEITPUNKT',
#   'zaehlpunkt': 'AT0010000000000000001000014166809',
#   'startAt': '2022-07-17T22:00:00Z',
# ...
